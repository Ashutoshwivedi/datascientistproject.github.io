# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
poke=pd.read_csv('/content/Pokemon Data.csv')

# %%
poke.head()
# Out:
#    Number        Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Atk  \
# 0       1   Bulbasaur  Grass  Poison  505.0  60      92       55      65
# 1       2     Ivysaur  Grass  Poison  270.0  46      45       70      80
# 2       3    Venusaur  Grass  Poison  435.0  66      75       85     100
# 3       4  Charmander   Fire     NaN  245.0  76      45       55      65
# 4       5  Charmeleon   Fire     NaN  455.0  55     110       80      85
#
#    Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0      65  ...  Green       True    0.875     Monster        Grass
# 1      80  ...  Green       True    0.875     Monster        Grass
# 2     100  ...  Green       True    0.875     Monster        Grass
# 3      70  ...    Red       True    0.875     Monster       Dragon
# 4      35  ...    Red       True    0.875     Monster       Dragon
#
#    hasMegaEvolution Height_m Weight_kg  Catch_Rate      Body_Style
# ...

# %%
poke.rename(columns={'Type_1': 'Primary_Type', 'Type_2':'Secondary_Type'},inplace=True)

# %%
poke.head()
# Out:
#    Number        Name Primary_Type Secondary_Type  Total  HP  Attack  Defense  \
# 0       1   Bulbasaur        Grass         Poison  505.0  60      92       55
# 1       2     Ivysaur        Grass         Poison  270.0  46      45       70
# 2       3    Venusaur        Grass         Poison  435.0  66      75       85
# 3       4  Charmander         Fire            NaN  245.0  76      45       55
# 4       5  Charmeleon         Fire            NaN  455.0  55     110       80
#
#    Sp_Atk  Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0      65      65  ...  Green       True    0.875     Monster        Grass
# 1      80      80  ...  Green       True    0.875     Monster        Grass
# 2     100     100  ...  Green       True    0.875     Monster        Grass
# 3      65      70  ...    Red       True    0.875     Monster       Dragon
# 4      85      35  ...    Red       True    0.875     Monster       Dragon
#
# ...

# %%
poke['Secondary_Type']=="Grass"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 716    False
# 717    False
# 718    False
# 719    False
# 720    False
# Name: Secondary_Type, Length: 721, dtype: bool

# %%
poke['Primary_Type']=="Grass"
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 716    False
# 717    False
# 718    False
# 719    False
# 720    False
# Name: Primary_Type, Length: 721, dtype: bool

# %%
grass_pokeman=poke[poke['Primary_Type']=="Grass"]

# %%
grass_pokeman.head()
# Out:
#     Number       Name Primary_Type Secondary_Type  Total  HP  Attack  Defense  \
# 0        1  Bulbasaur        Grass         Poison  505.0  60      92       55
# 1        2    Ivysaur        Grass         Poison  270.0  46      45       70
# 2        3   Venusaur        Grass         Poison  435.0  66      75       85
# 42      43     Oddish        Grass         Poison  490.0  61      50       55
# 43      44      Gloom        Grass         Poison  325.0  88      65       70
#
#     Sp_Atk  Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0       65      65  ...  Green       True    0.875     Monster        Grass
# 1       80      80  ...  Green       True    0.875     Monster        Grass
# 2      100     100  ...  Green       True    0.875     Monster        Grass
# 42      75      65  ...   Blue       True    0.500       Grass          NaN
# 43      85      75  ...   Blue       True    0.500       Grass          NaN
#
# ...

# %%
water_pokeman=poke[poke['Primary_Type']=="Water"]

# %%
water_pokeman.head()
# Out:
#     Number       Name Primary_Type Secondary_Type  Total  HP  Attack  Defense  \
# 6        7   Squirtle        Water            NaN  395.0  70      83       60
# 7        8  Wartortle        Water            NaN  490.0  50      95       25
# 8        9  Blastoise        Water            NaN  285.0  80     125       50
# 53      54    Psyduck        Water            NaN  525.0  62      52       48
# 54      55    Golduck        Water            NaN  310.0  78      82       78
#
#     Sp_Atk  Sp_Def  ...   Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 6       25      31  ...    Blue       True    0.875     Monster      Water_1
# 7       90      61  ...    Blue       True    0.875     Monster      Water_1
# 8       20      54  ...    Blue       True    0.875     Monster      Water_1
# 53      65      50  ...  Yellow       True    0.500     Water_1        Field
# 54      95      80  ...    Blue       True    0.500     Water_1        Field
#
# ...

# %%
fire_pokeman=poke[poke['Primary_Type']=="Fire"]

# %%
fire_pokeman.head()
# Out:
#     Number        Name Primary_Type Secondary_Type  Total   HP  Attack  \
# 3        4  Charmander         Fire            NaN  245.0   76      45
# 4        5  Charmeleon         Fire            NaN  455.0   55     110
# 5        6   Charizard         Fire         Flying  320.0   95      50
# 36      37      Vulpix         Fire            NaN  300.0   89      41
# 37      38   Ninetales         Fire            NaN  390.0  125      76
#
#     Defense  Sp_Atk  Sp_Def  ...   Color  hasGender  Pr_Male Egg_Group_1  \
# 3        55      65      70  ...     Red       True    0.875     Monster
# 4        80      85      35  ...     Red       True    0.875     Monster
# 5        50      20      70  ...     Red       True    0.875     Monster
# 36       40      50      80  ...   Brown       True    0.250       Field
# 37       75      81      35  ...  Yellow       True    0.250       Field
#
#     Egg_Group_2  hasMegaEvolution Height_m Weight_kg  Catch_Rate  \
# ...

# %%
poke.shape
# Out:
# (721, 23)

# %%
grass_pokeman.shape
# Out:
# (66, 23)

# %%
water_pokeman.shape
# Out:
# (105, 23)

# %%
fire_pokeman.shape
# Out:
# (47, 23)

# %%
(105+66+47)/721
# Out:
# 0.30235783633841884

# %%
grass_pokeman.head()
# Out:
#     Number       Name Primary_Type Secondary_Type  Total  HP  Attack  Defense  \
# 0        1  Bulbasaur        Grass         Poison  505.0  60      92       55
# 1        2    Ivysaur        Grass         Poison  270.0  46      45       70
# 2        3   Venusaur        Grass         Poison  435.0  66      75       85
# 42      43     Oddish        Grass         Poison  490.0  61      50       55
# 43      44      Gloom        Grass         Poison  325.0  88      65       70
#
#     Sp_Atk  Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0       65      65  ...  Green       True    0.875     Monster        Grass
# 1       80      80  ...  Green       True    0.875     Monster        Grass
# 2      100     100  ...  Green       True    0.875     Monster        Grass
# 42      75      65  ...   Blue       True    0.500       Grass          NaN
# 43      85      75  ...   Blue       True    0.500       Grass          NaN
#
# ...

# %%
sns.histplot(grass_pokeman['Speed'],color="G")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:516: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   scout = self.ax.fill_between([], [], color=color, **plot_kws)

# %%
sns.histplot(grass_pokeman['Sp_Atk'],color="Y")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:516: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   scout = self.ax.fill_between([], [], color=color, **plot_kws)

# %%
sns.histplot(grass_pokeman['Sp_Def'],color="R")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:516: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   scout = self.ax.fill_between([], [], color=color, **plot_kws)

# %%
grass_pokeman.describe()
# Out:
#            Number       Total          HP      Attack     Defense      Sp_Atk  \
# count   66.000000   66.000000   66.000000   66.000000   66.000000   66.000000
# mean   347.454545  398.560606   65.924242   71.196970   69.590909   74.333333
# std    200.262380  104.845987   19.575739   24.219649   23.893338   24.570986
# min      1.000000  180.000000   30.000000   27.000000   30.000000   24.000000
# 25%    187.250000  313.750000   50.000000   53.500000   50.000000   55.250000
# 50%    372.000000  407.500000   63.500000   69.000000   65.000000   74.500000
# 75%    507.500000  486.750000   75.000000   90.000000   84.500000   91.500000
# max    673.000000  600.000000  123.000000  130.000000  131.000000  125.000000
#
#            Sp_Def       Speed  Generation    Pr_Male   Height_m   Weight_kg  \
# count   66.000000   66.000000   66.000000  64.000000  66.000000   66.000000
# mean    68.863636   59.515152    3.378788   0.607422   0.984394   38.109091
# ...

# %%
water_pokeman.head()
# Out:
#     Number       Name Primary_Type Secondary_Type  Total  HP  Attack  Defense  \
# 6        7   Squirtle        Water            NaN  395.0  70      83       60
# 7        8  Wartortle        Water            NaN  490.0  50      95       25
# 8        9  Blastoise        Water            NaN  285.0  80     125       50
# 53      54    Psyduck        Water            NaN  525.0  62      52       48
# 54      55    Golduck        Water            NaN  310.0  78      82       78
#
#     Sp_Atk  Sp_Def  ...   Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 6       25      31  ...    Blue       True    0.875     Monster      Water_1
# 7       90      61  ...    Blue       True    0.875     Monster      Water_1
# 8       20      54  ...    Blue       True    0.875     Monster      Water_1
# 53      65      50  ...  Yellow       True    0.500     Water_1        Field
# 54      95      80  ...    Blue       True    0.500     Water_1        Field
#
# ...

# %%
sns.histplot(water_pokeman['Speed'],color="G")
plt.show()

# %%
sns.histplot(water_pokeman['Sp_Atk'],color="Y")
plt.show()

# %%
sns.histplot(water_pokeman['Sp_Def'],color="R")
plt.show()

# %%
water_pokeman.describe()
# Out:
#            Number       Total          HP      Attack     Defense      Sp_Atk  \
# count  105.000000  105.000000  105.000000  105.000000  105.000000  105.000000
# mean   305.895238  426.571429   71.209524   72.085714   69.438095   71.095238
# std    187.287003  107.906642   27.552291   25.557670   25.858685   26.792839
# min      7.000000  200.000000   20.000000   10.000000   20.000000   10.000000
# 25%    131.000000  330.000000   53.000000   53.000000   50.000000   53.000000
# 50%    278.000000  455.000000   70.000000   70.000000   67.000000   70.000000
# 75%    457.000000  500.000000   90.000000   90.000000   85.000000   90.000000
# max    693.000000  680.000000  170.000000  130.000000  180.000000  150.000000
#
#            Sp_Def       Speed  Generation    Pr_Male    Height_m   Weight_kg  \
# count  105.000000  105.000000  105.000000  97.000000  105.000000  105.000000
# mean    67.095238   64.971429    2.885714   0.587629    1.321143   53.576190
# ...

# %%
fire_pokeman.head()
# Out:
#     Number        Name Primary_Type Secondary_Type  Total   HP  Attack  \
# 3        4  Charmander         Fire            NaN  245.0   76      45
# 4        5  Charmeleon         Fire            NaN  455.0   55     110
# 5        6   Charizard         Fire         Flying  320.0   95      50
# 36      37      Vulpix         Fire            NaN  300.0   89      41
# 37      38   Ninetales         Fire            NaN  390.0  125      76
#
#     Defense  Sp_Atk  Sp_Def  ...   Color  hasGender  Pr_Male Egg_Group_1  \
# 3        55      65      70  ...     Red       True    0.875     Monster
# 4        80      85      35  ...     Red       True    0.875     Monster
# 5        50      20      70  ...     Red       True    0.875     Monster
# 36       40      50      80  ...   Brown       True    0.250       Field
# 37       75      81      35  ...  Yellow       True    0.250       Field
#
#     Egg_Group_2  hasMegaEvolution Height_m Weight_kg  Catch_Rate  \
# ...

# %%
sns.histplot(fire_pokeman['Speed'],color="G")
plt.show()

# %%
sns.histplot(fire_pokeman['Sp_Atk'],color="Y")
plt.show()

# %%
sns.histplot(fire_pokeman['Sp_Def'],color="R")
plt.show()

# %%
fire_pokeman.describe()
# Out:
#            Number       Total          HP      Attack     Defense      Sp_Atk  \
# count   47.000000   47.000000   47.000000   47.000000   47.000000   47.000000
# mean   337.829787  423.191489   71.808511   82.319149   65.021277   81.787234
# std    225.660992  111.951200   20.432964   26.182558   22.581725   27.032940
# min      4.000000  205.000000   39.000000   40.000000   37.000000   15.000000
# 25%    150.500000  324.000000   59.500000   60.000000   49.000000   65.000000
# 50%    322.000000  418.000000   70.000000   84.000000   60.000000   80.000000
# 75%    513.500000  503.000000   82.500000  100.000000   72.000000  102.000000
# max    721.000000  680.000000  125.000000  140.000000  140.000000  130.000000
#
#            Sp_Def       Speed  Generation    Pr_Male   Height_m   Weight_kg  \
# count   47.000000   47.000000   47.000000  43.000000  47.000000   47.000000
# mean    67.872340   72.680851    3.276596   0.683140   1.163617   63.976596
# ...

# %%
water_pokeman.describe()
# Out:
#            Number       Total          HP      Attack     Defense      Sp_Atk  \
# count  105.000000  105.000000  105.000000  105.000000  105.000000  105.000000
# mean   305.895238  426.571429   71.209524   72.085714   69.438095   71.095238
# std    187.287003  107.906642   27.552291   25.557670   25.858685   26.792839
# min      7.000000  200.000000   20.000000   10.000000   20.000000   10.000000
# 25%    131.000000  330.000000   53.000000   53.000000   50.000000   53.000000
# 50%    278.000000  455.000000   70.000000   70.000000   67.000000   70.000000
# 75%    457.000000  500.000000   90.000000   90.000000   85.000000   90.000000
# max    693.000000  680.000000  170.000000  130.000000  180.000000  150.000000
#
#            Sp_Def       Speed  Generation    Pr_Male    Height_m   Weight_kg  \
# count  105.000000  105.000000  105.000000  97.000000  105.000000  105.000000
# mean    67.095238   64.971429    2.885714   0.587629    1.321143   53.576190
# ...

# %%
poke.head()
# Out:
#    Number        Name Primary_Type Secondary_Type  Total  HP  Attack  Defense  \
# 0       1   Bulbasaur        Grass         Poison  505.0  60      92       55
# 1       2     Ivysaur        Grass         Poison  270.0  46      45       70
# 2       3    Venusaur        Grass         Poison  435.0  66      75       85
# 3       4  Charmander         Fire            NaN  245.0  76      45       55
# 4       5  Charmeleon         Fire            NaN  455.0  55     110       80
#
#    Sp_Atk  Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0      65      65  ...  Green       True    0.875     Monster        Grass
# 1      80      80  ...  Green       True    0.875     Monster        Grass
# 2     100     100  ...  Green       True    0.875     Monster        Grass
# 3      65      70  ...    Red       True    0.875     Monster       Dragon
# 4      85      35  ...    Red       True    0.875     Monster       Dragon
#
# ...

# %%
poke['hasMegaEvolution'].value_counts()
# Out:
# False    675
# True      46
# Name: hasMegaEvolution, dtype: int64

# %%
46/721
# Out:
# 0.0638002773925104

# %%
x = poke[['Speed']]

# %%
y = poke[['hasMegaEvolution']]

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split(x,y,test_size=0.3)
# Out:
# [     Speed
#  706     75
#  101     40
#  509    106
#  585     95
#  303     30
#  ..     ...
#  544    112
#  658     57
#  60      90
#  612     40
#  444    102
#
#  [504 rows x 1 columns],      Speed
#  631    109
#  541     92
#  504     77
#  38      20
#  306     60
#  ..     ...
#  4       20
#  569     65
#  150    100
#  640    111
#  438     60
#
#  [217 rows x 1 columns],      hasMegaEvolution
#  706             False
#  101             False
#  509             False
#  585             False
#  303             False
#  ..                ...
#  544             False
#  658             False
#  60              False
#  612             False
#  444              True
#
#  [504 rows x 1 columns],      hasMegaEvolution
#  631             False
#  541             False
#  504             False
#  38              False
#  306             False
#  ..                ...
#  4               False
#  569             False
#  150             False
#  640             False
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dtc.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[201,   5],
#        [ 11,   0]])

# %%
poke.head()
# Out:
#    Number        Name Primary_Type Secondary_Type  Total  HP  Attack  Defense  \
# 0       1   Bulbasaur        Grass         Poison  505.0  60      92       55
# 1       2     Ivysaur        Grass         Poison  270.0  46      45       70
# 2       3    Venusaur        Grass         Poison  435.0  66      75       85
# 3       4  Charmander         Fire            NaN  245.0  76      45       55
# 4       5  Charmeleon         Fire            NaN  455.0  55     110       80
#
#    Sp_Atk  Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0      65      65  ...  Green       True    0.875     Monster        Grass
# 1      80      80  ...  Green       True    0.875     Monster        Grass
# 2     100     100  ...  Green       True    0.875     Monster        Grass
# 3      65      70  ...    Red       True    0.875     Monster       Dragon
# 4      85      35  ...    Red       True    0.875     Monster       Dragon
#
# ...

# %%
x = poke[['Defense']]

# %%
y = poke[['Attack']]

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split(x,y,test_size=0.3)
# Out:
# [     Defense
#  588      105
#  482      120
#  96        70
#  319       35
#  213       75
#  ..       ...
#  23        78
#  599       95
#  280       35
#  569       40
#  299       45
#
#  [504 rows x 1 columns],      Defense
#  249       90
#  512       48
#  675       60
#  333       90
#  251       35
#  ..       ...
#  424       34
#  28        55
#  385       50
#  69        50
#  613       80
#
#  [217 rows x 1 columns],      Attack
#  588     135
#  482     120
#  96       73
#  319      70
#  213     125
#  ..      ...
#  23       85
#  599      80
#  280      35
#  569      65
#  299      45
#
#  [504 rows x 1 columns],      Attack
#  249     130
#  512      53
#  675      80
#  333      70
#  251      45
#  ..      ...
#  424      50
#  28       47
#  385     150
#  69       90
#  613     110
#
#  [217 rows x 1 columns]]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dtr.predict(x_test)
# Out:
# array([100.        ,  60.81818182,  79.38709677,  88.        ,
#         79.38709677,  69.        ,  90.33333333,  60.81818182,
#         92.66666667,  78.08823529,  60.20833333,  81.33333333,
#         49.2       ,  78.08823529,  86.        ,  79.38709677,
#         60.20833333,  78.33333333, 111.66666667,  94.71428571,
#        105.        , 100.        ,  91.47826087,  60.20833333,
#         79.38709677,  81.33333333,  63.3       ,  60.20833333,
#         63.11111111,  94.71428571,  81.33333333,  78.76190476,
#         88.        ,  81.33333333, 100.        , 112.        ,
#         30.        ,  91.47826087,  81.33333333,  79.38709677,
#         79.38709677,  78.08823529,  49.2       ,  63.3       ,
#         60.81818182,  60.20833333,  78.08823529,  95.25      ,
#         92.66666667,  55.66666667, 101.25      , 111.66666667,
#         83.33333333,  79.38709677,  45.        ,  90.5       ,
#         79.5       ,  94.71428571,  94.71428571,  78.08823529,
# ...

# %%
y_pred=dtr.predict(x_test)

# %%
y_test.head()
# Out:
#      Attack
# 212      10
# 224      55
# 408     165
# 451      90
# 10       10

# %%
y_pred[0:5]
# Out:
# array([100.        ,  60.81818182,  79.38709677,  88.        ,
#         79.38709677])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 775.5646730097792

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import datetime as dt
import numpy as np

# %%
#importing main dataset
df = pd.read_csv('/content/COVID_19 INDIA - Sheet1.csv', parse_dates=['Date'], dayfirst=True)

# %%
df.head()
# Out:
#         Date     Time                     State/UT  Confirmed Cases  \
# 0 2021-02-14  6.30 PM  Andaman and Nicobar Islands            10051
# 1 2021-02-15  6.30 PM               Andhra Pradesh          2319364
# 2 2021-02-16  6.30 PM            Arunachal Pradesh            64644
# 3 2021-02-17  6.30 PM                        Assam          7235293
# 4 2021-02-18  6.30 PM                        Bihar           830452
#
#    Active Cases  Cured/Discharged  Death
# 0            31              9501    129
# 1           450           2264148  14730
# 2            52             65486    296
# 3          1365            732190   6639
# 4            55            816444  12256

# %%
#keeping only required columns
df = df[['Date', 'State/UT', 'Cured/Discharged', 'Death', 'Confirmed Cases']]


#remaining column names
df.columns = ['date', 'state', 'cured', 'death', 'confirmed']

# %%
  #looking at the earlier dates
  df.head()
# Out:
#         date                        state    cured  death  confirmed
# 0 2021-02-14  Andaman and Nicobar Islands     9501    129      10051
# 1 2021-02-15               Andhra Pradesh  2264148  14730    2319364
# 2 2021-02-16            Arunachal Pradesh    65486    296      64644
# 3 2021-02-17                        Assam   732190   6639    7235293
# 4 2021-02-18                        Bihar   816444  12256     830452

# %%
  df.tail()
# Out:
#          date          state    cured  death  confirmed
# 58 2021-03-12      Telangana   786241  10600     790989
# 59 2021-03-13        Tripura    99951   4132     100871
# 60 2021-03-14  Uttar Pradesh  2046249  23492    2070441
# 61 2021-03-15    Uttarakhand   432032   7691     437092
# 62 2021-03-16    West Bengal  1994974  21197    2016976

# %%
#current date
today = df[df.date == '2021-02-15']

# %%
today
# Out:
#          date           state    cured  death  confirmed
# 1  2021-02-15  Andhra Pradesh  2264148  14730    2319364
# 37 2021-02-15       Rajasthan  1272873  26148    1282745

# %%
today.head()
# Out:
#          date           state    cured  death  confirmed
# 1  2021-02-15  Andhra Pradesh  2264148  14730    2319364
# 37 2021-02-15       Rajasthan  1272873  26148    1282745

# %%
#Sorting data w.r.t number of confirmed cases
max_confirmed_cases=today.sort_values(by="confirmed",ascending=False)
max_confirmed_cases
# Out:
#          date           state    cured  death  confirmed
# 1  2021-02-15  Andhra Pradesh  2264148  14730    2319364
# 37 2021-02-15       Rajasthan  1272873  26148    1282745

# %%
#Getting states with maximum number of confirmed cases
top_states_confirmed=max_confirmed_cases[0:5]

# %%
top_states_confirmed
# Out:
#          date           state    cured  death  confirmed
# 1  2021-02-15  Andhra Pradesh  2264148  14730    2319364
# 37 2021-02-15       Rajasthan  1272873  26148    1282745

# %%
#Making bar-plot for states with top confirmed cases
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="state", y="confirmed",data=top_states_confirmed,hue="state")
plt.show()

# %%
# Sorting data w.r.t number of death cases
max_death_cases=today.sort_values(by="death",ascending=False)
max_death_cases
# Out:
#          date           state    cured  death  confirmed
# 37 2021-02-15       Rajasthan  1272873  26148    1282745
# 1  2021-02-15  Andhra Pradesh  2264148  14730    2319364

# %%
# Getting states with maximum number of death cases
top_states_death=max_death_cases[0:5]

# %%
#Making bar-plot for states with top death cases
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="state", y="death",data=top_states_death,hue="state")
plt.show()

# %%
#Sorting data w.r.t number of cured cases
max_cured_cases=today.sort_values(by="cured",ascending=False)
max_cured_cases
# Out:
#          date           state    cured  death  confirmed
# 1  2021-02-15  Andhra Pradesh  2264148  14730    2319364
# 37 2021-02-15       Rajasthan  1272873  26148    1282745

# %%
# Getting states with maximum number of cured cases
top_states_cured=max_cured_cases[0:5]

# %%
#Making bar-plot for states with top cured cases
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="state", y="cured",data=top_states_death,hue="state")
plt.show()

# %%
#Sorting data w.r.t number of cured cases
max_cured_cases=today.sort_values(by="cured",ascending=False)
max_cured_cases
# Out:
#          date           state    cured  death  confirmed
# 1  2021-02-15  Andhra Pradesh  2264148  14730    2319364
# 37 2021-02-15       Rajasthan  1272873  26148    1282745

# %%
# Getting states with maximum number of cured cases
top_states_cured=max_cured_cases[0:5]

# %%
#Making bar-plot for states with top death cases
sns.set(rc={'figure.figsize':(15,10)})
sns.barplot(x="state", y="cured",data=top_states_death,hue="state")
plt.show()

# %%
#Maharashtra
maha = df[df.state == 'Maharashtra']

# %%
maha
# Out:
#          date        state    cured   death  confirmed
# 20 2021-03-06  Maharashtra  7723959  143769     242565
# 47 2021-03-01  Maharashtra  7723959  143769     242565

# %%
#visualizing confirmed cases in maharashtra
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date", y="confirmed",data=maha,color="g")
plt.show()

# %%
#visualizing death cases in maharashtra
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date", y="death",data=maha,color="r")
plt.show()

# %%
#Assam
Ass = df[df.state =='Assam']

# %%
Ass
# Out:
#         date  state   cured  death  confirmed
# 3 2021-02-17  Assam  732190   6639    7235293

# %%
#visualizing confirmed cases in Assam
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date", y="confirmed",data= Ass,color="g")
plt.show()

# %%
#visualizing death cases in Assam
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date", y="death",data=Ass,color="r")
plt.show()

# %%
#Uttarakhand
UK = df[df.state == 'Uttarakhand']

# %%
UK
# Out:
#          date        state   cured  death  confirmed
# 34 2021-03-20  Uttarakhand  428809   7691     437092
# 43 2021-02-21  Uttarakhand  428809   7691     437092
# 61 2021-03-15  Uttarakhand  432032   7691     437092

# %%
#visualizing confirmed cases in Uttarakhand
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="confirmed", y="cured",data=UK,color="g")
plt.show()

# %%
#visualizing death cases in Uttarakhand
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date", y="death",data=UK,color="r")
plt.show()

# %% [markdown]
# #**LR & FR**

# %%
#Linear regression
from sklearn.model_selection import train_test_split

# %%
maha
# Out:
#          date        state    cured   death  confirmed
# 20 2021-03-06  Maharashtra  7723959  143769     242565
# 47 2021-03-01  Maharashtra  7723959  143769     242565

# %%
#Converting date-time to ordinal
maha['date']=maha['date'].map(dt.datetime.toordinal)
maha.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       date        state    cured   death  confirmed
# 20  737855  Maharashtra  7723959  143769     242565
# 47  737850  Maharashtra  7723959  143769     242565

# %%
#getting dependent variable  and independent variable
x=maha['date']
y=maha['confirmed']

# %%
x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
y_train
# Out:
# 20    242565
# Name: confirmed, dtype: int64

# %%
lr.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression()

# %%
maha.tail()
# Out:
#       date        state    cured   death  confirmed
# 20  737855  Maharashtra  7723959  143769     242565
# 47  737850  Maharashtra  7723959  143769     242565

# %%
lr.predict(np.array([[737850]]))
# Out:
# array([[242565.]])
